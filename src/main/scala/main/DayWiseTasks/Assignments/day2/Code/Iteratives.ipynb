// %%
// Basic for loop
for (i <- 1 to 5) {
  println(s"Iteration: $i")
}
// Out:
// Iteration: 1
// Iteration: 2
// Iteration: 3
// Iteration: 4
// Iteration: 5

// %%
// for loop using `until`
for (i <- 1 until 5) {
  println(s"Iteration: $i")
}
// Out:
// Iteration: 1
// Iteration: 2
// Iteration: 3
// Iteration: 4

// %%
// Nested for loop
for (i <- 1 to 2; j <- 1 to 3) {
  println(s"i: $i, j: $j")
}
// Out:
// i: 1, j: 1
// i: 1, j: 2
// i: 1, j: 3
// i: 2, j: 1
// i: 2, j: 2
// i: 2, j: 3

// %%
// for loop with a condition
for (i <- 1 to 10 if i % 2 == 0) {
  println(s"Even number: $i")
}
// Out:
// Even number: 2
// Even number: 4
// Even number: 6
// Even number: 8
// Even number: 10

// %%
// Basic while loop
var count = 1
while (count <= 5) {
  println(s"Count: $count")
  count += 1
}
// Out:
// Count: 1
// Count: 2
// Count: 3
// Count: 4
// Count: 5
// count = 6
// 6

// %%
// do-while loop
var num = 1
do {
  println(s"Number: $num")
  num += 1
} while (num <= 5)
// Out:
// Number: 1
// Number: 2
// Number: 3
// Number: 4
// Number: 5
// num = 6
// 6

// %%
// Iterating over a collection using foreach
val colors = List("Red", "Blue", "Green")
colors.foreach(color => println(s"Color: $color"))
// Out:
// Color: Red
// Color: Blue
// Color: Green
// colors = List(Red, Blue, Green)
// List(Red, Blue, Green)

// %%
// Using map to transform a collection
val numbers = List(1, 2, 3, 4)
val squared = numbers.map(num => num * num)
println(s"Squared numbers: $squared")
// Out:
// Squared numbers: List(1, 4, 9, 16)
// numbers = List(1, 2, 3, 4)
// squared = List(1, 4, 9, 16)
// List(1, 4, 9, 16)

// %%
// for comprehension to generate a new collection
val doubledNumbers = for (num <- numbers) yield num * 2
println(s"Doubled numbers: $doubledNumbers")
// Out:
// Doubled numbers: List(2, 4, 6, 8)
// doubledNumbers = List(2, 4, 6, 8)
// List(2, 4, 6, 8)
